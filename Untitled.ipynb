# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train/ 255.0, x_test/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 11s 1us/step

# %%
plt.figure(figsize=(5,5))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.axis('off')
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Conv2D(64, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(x_train.reshape(-1,28,28,1), y_train, epochs=10, validation_data=(x_test.reshape(-1,28,28,1), y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 14ms/step - accuracy: 0.9093 - loss: 0.2828 - val_accuracy: 0.9838 - val_loss: 0.0528
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.9864 - loss: 0.0427 - val_accuracy: 0.9873 - val_loss: 0.0392
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.9910 - loss: 0.0282 - val_accuracy: 0.9899 - val_loss: 0.0283
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.9939 - loss: 0.0189 - val_accuracy: 0.9890 - val_loss: 0.0310
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.9949 - loss: 0.0142 - val_accuracy: 0.9908 - val_loss: 0.0326
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.9967 - loss: 0.0103 - val_accuracy: 0.9901 - val_loss: 0.0380
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9973 - loss: 0.0073 - val_accuracy: 0.9895 - val_loss: 0.0356
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.9977 - loss: 0.0065 - val_accuracy: 0.9913 - val_loss: 0.0362
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9976 - loss: 0.0066 - val_accuracy: 0.9914 - val_loss: 0.0349
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 25s 13ms/step - accuracy: 0.9983 - loss: 0.0052 - val_accuracy: 0.9879 - val_loss: 0.0542

# %%
test_loss, test_acc = model.evaluate(x_test.reshape(-1,28,28,1), y_test)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9857 - loss: 0.0698
# Test Accuracy: 98.79%

# %%
predictions = model.predict(x_test.reshape(-1,28,28,1))

# Plot an example
index = 5
plt.imshow(x_test[index], cmap='gray')
plt.title(f"Predicted: {np.argmax(predictions[index])}")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step

# %%
predictions = model.predict(x_test.reshape(-1,28,28,1))

# Plot an example
index = 10
plt.imshow(x_test[index], cmap='gray')
plt.title(f"Predicted: {np.argmax(predictions[index])}")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
